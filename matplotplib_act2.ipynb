# %%
import matplotlib as plt
import matplotlib.pyplot as plt

# %%
import pandas as pd


data = pd.read_csv('company_sales_data.csv')

plt.plot(data['month_number'], data['total_profit'])
plt.xlabel('Month Number')
plt.ylabel('Total profit')
plt.title('Company Total Profit per Month')
plt.show()

# %%
# Q2
plt.bar(data['month_number'] - bar_width/2, data['facecream'], width=bar_width, label='Face Cream sales data')
plt.bar(data['month_number'] + bar_width/2, data['facewash'], width=bar_width, label='Face Wash sales data')
plt.legend(loc='upper left')
plt.xlabel('Month Number')
plt.ylabel('Units Sold')
plt.title('Face Cream and Face Wash Sales per Month')
plt.show()

# %%
# Calculate total units sold per product for the year
products = ['facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo', 'moisturizer']
total_sales = [data[product].sum() for product in products]

plt.pie(total_sales, labels=products, autopct='%1.1f%%', startangle=140)
plt.title('Sales Data')
plt.legend(products, title="Products")
plt.show()
